# %%
#initiation routines

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.support.select import Select
from selenium.webdriver.common import keys
import time
browser = webdriver.Chrome('C:\\Users\\Pranav Ramkumar\\Downloads\\chromedriver')

# %%
# load data

# %%
df = pd.read_csv("filename.csv", encoding = "utf-8")

# %%
df
# Out:
#                                                 Source  \
# 0                    /a-manifesto-for-the-fragile-city
# 1            /global-competition-for-brains-and-talent
# 2    /are-syrias-do-it-yourself-refugees-outliers-o...
# 3    /exploitation-in-migration-unacceptable-but-in...
# 4    /preventing-mass-atrocities-against-the-statel...
# ..                                                 ...
# 212  /us-foreign-assistance-africa-securing-america...
# 213    /obama-and-africa-matching-expectations-reality
# 214                                             /cover
# 215  /financial-diplomacy-and-credit-crunch-rise-ce...
# 216  /historical-reconciliation-redress-rights-and-...
#
#                                                 Target
# 0                         /news/manifesto-fragile-city
# 1           /news/global-competition-brains-and-talent
# 2    /news/are-syrias-do-it-yourself-refugees-outli...
# 3    /news/exploitation-migration-unacceptable-inev...
# 4    /news/preventing-mass-atrocities-against-state...
# ..                                                 ...
# 212  /news/us-foreign-assistance-africa-securing-am...
# 213  /news/obama-and-africa-matching-expectations-r...
# 214                                        /news/cover
# 215  /news/financial-diplomacy-and-credit-crunch-ri...
# 216  /news/historical-reconciliation-redress-rights...
#
# [217 rows x 2 columns]

# %%
#authentication routines

# %%
browser.get('https://ias:dev@jia.site.drupaldisttest.cc.columbia.edu/user')
uni = browser.find_element_by_id('username')
uni.send_keys('uni')
pwd = browser.find_element_by_id('password')
pwd.send_keys('pwd')
elem = browser.find_element_by_name('submit')
elem.click()
browser.get('https://ias:dev@jia.site.drupaldisttest.cc.columbia.edu')

# %%
# populate

# %%
browser.get('https://web.archive.org/web/20160627211303/https://jia.sipa.columbia.edu'+df.iloc[0,0])

# %%
# Out:
#                                                 Source  \
# 0                    /a-manifesto-for-the-fragile-city
# 1            /global-competition-for-brains-and-talent
# 2    /are-syrias-do-it-yourself-refugees-outliers-o...
# 3    /exploitation-in-migration-unacceptable-but-in...
# 4    /preventing-mass-atrocities-against-the-statel...
# ..                                                 ...
# 212  /us-foreign-assistance-africa-securing-america...
# 213    /obama-and-africa-matching-expectations-reality
# 214                                             /cover
# 215  /financial-diplomacy-and-credit-crunch-rise-ce...
# 216  /historical-reconciliation-redress-rights-and-...
#
#                                                 Target  PostDate
# 0                         /news/manifesto-fragile-city  0.000495
# 1           /news/global-competition-brains-and-talent  0.000495
# 2    /news/are-syrias-do-it-yourself-refugees-outli...  0.000495
# 3    /news/exploitation-migration-unacceptable-inev...  0.000495
# 4    /news/preventing-mass-atrocities-against-state...  0.000495
# ..                                                 ...       ...
# 212  /news/us-foreign-assistance-africa-securing-am...  0.000495
# 213  /news/obama-and-africa-matching-expectations-r...  0.000495
# 214                                        /news/cover  0.000495
# 215  /news/financial-diplomacy-and-credit-crunch-ri...  0.000495
# 216  /news/historical-reconciliation-redress-rights...  0.000495
#
# [217 rows x 3 columns]
